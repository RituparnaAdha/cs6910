# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import models, optimizers, activations
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
class CNN(object):
    def __init__():
        return
    def __new__(self, input_shape, no_of_filters, filters, activation_function, pool_size, neurons_in_dense_layer):

        #input layer
        model = models.Sequential()
        model.add(Conv2D(no_of_filters[0], filters[0], input_shape = input_shape))
        model.add(Activation(activation_function))    
        model.add(MaxPooling2D(pool_size))

        #convolutional layers
        _layers = range(1, len(filters))
        for _layer in _layers:
     
            model.add(Conv2D(no_of_filters[_layer], filters[_layer]))
            model.add(Activation(activation_function))
            model.add(MaxPooling2D(pool_size))

        #dense layer
        model.add(Flatten())
        model.add(Dense(neurons_in_dense_layer))
        model.add(Activation(activation_function))
        
        #output layer
        model.add(Dense(10))
        model.add(Activation('softmax'))
        model.summary()
        
        return model

if __name__ == "__main__":
    m = 32 #no. of filter in each layer
    no_of_filters = [5]*5
    k = 3 #layer size  
    filters = [(k, k)] * 5
    activation_function = "relu"
    neurons_in_dense_layer = 32
    
    pool_size = (2, 2)
    input_shape=(500,500,3)
    
    cnn_model = CNN(input_shape, no_of_filters, filters, activation_function, pool_size, neurons_in_dense_layer)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 498, 498, 5)       140
# _________________________________________________________________
# activation (Activation)      (None, 498, 498, 5)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 249, 249, 5)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 247, 247, 5)       230
# _________________________________________________________________
# activation_1 (Activation)    (None, 247, 247, 5)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 123, 123, 5)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 121, 121, 5)       230
# _________________________________________________________________
# activation_2 (Activation)    (None, 121, 121, 5)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 60, 5)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 58, 58, 5)         230
# _________________________________________________________________
# activation_3 (Activation)    (None, 58, 58, 5)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 29, 29, 5)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 27, 27, 5)         230
# _________________________________________________________________
# activation_4 (Activation)    (None, 27, 27, 5)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 5)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 845)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                27072
# _________________________________________________________________
# activation_5 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 28,462
# Trainable params: 28,462
# Non-trainable params: 0
# _________________________________________________________________
